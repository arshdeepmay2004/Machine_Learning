# %%
import spacy

# %%
# s!python -m spacy download en_core_web_sm

# %%
nlp=spacy.load("en_core_web_sm") # sm(small) ,md(medium) , lg(large)

# %%
text=nlp("Hello. My name is Mr. Arshdeep singh. Currently im purcuing B.Tech CSE/AIML. Right now I'm learmning natural languge prpocessing")
text2=("Hello. My name is Mr. Arshdeep singh. Currently im purcuing B.Tech CSE/AIML. Right now. I'm learmning natural languge prpocessing")

# %%
text2.split(".")
# Out:
# ['Hello',
#  ' My name is Mr',
#  ' Arshdeep singh',
#  ' Currently im purcuing B',
#  'Tech CSE/AIML',
#  ' Right now',
#  " I'm learmning natural languge prpocessing"]

# %%
# sents is used to send data to nlp and it is than processed according to the model
for i in text.sents:
    print(i)
# Out:
# Hello.
# My name is Mr. Arshdeep singh.
# Currently im purcuing B.Tech CSE/AIML.
# Right now I'm learmning natural languge prpocessing

# %%
for i in text:
    print(i,"POS is", i.pos_,spacy.explain(i))
# Out:
# Hello POS is INTJ None
# . POS is PUNCT None
# My POS is PRON None
# name POS is NOUN None
# is POS is AUX None
# Mr. POS is PROPN None
# Arshdeep POS is PROPN None
# singh POS is NOUN None
# . POS is PUNCT None
# Currently POS is ADV None
# i POS is PRON None
# m POS is AUX None
# purcuing POS is VERB None
# B.Tech POS is PROPN None
# CSE POS is PROPN None
# / POS is SYM None
# AIML POS is PROPN None
# . POS is PUNCT None
# Right POS is ADV None
# now POS is ADV None
# I POS is PRON None
# 'm POS is AUX None
# learmning POS is VERB None
# natural POS is ADJ None
# languge POS is NOUN None
# prpocessing POS is VERB None
