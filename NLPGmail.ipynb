# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - ------------------------------------- 0.5/12.8 MB 295.4 kB/s eta 0:00:42
#      - ------------------------------------- 0.5/12.8 MB 295.4 kB/s eta 0:00:42
#      -- ------------------------------------ 0.8/12.8 MB 369.4 kB/s eta 0:00:33
#      -- ------------------------------------ 0.8/12.8 MB 369.4 kB/s eta 0:00:33
#      -- ------------------------------------ 0.8/12.8 MB 369.4 kB/s eta 0:00:33
# ...

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
email=nlp("Hello my name is Arshdeep Singh. My main gmail id is arshdeep.may.2004@gmail.com. And My other id's are arshdeep.jpg@gmail.com" \
"and arshdeep.2004.may@gmail.com also my another gmail id is arshdeep@yahoo.com ")

# %%
for i in email:
    if i.like_email: # like_num, like_url
        print(i)
# Out:
# arshdeep.may.2004@gmail.com
# arshdeep.jpg@gmail.comand
# arshdeep.2004.may@gmail.com
# arshdeep@yahoo.com
